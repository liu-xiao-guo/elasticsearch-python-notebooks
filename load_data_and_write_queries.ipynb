# %%
# !pip3 install elasticsearch nba_api
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: elasticsearch in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (8.12.0)
# Requirement already satisfied: nba_api in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.4.1)
# Requirement already satisfied: elastic-transport<9,>=8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from elasticsearch) (8.10.0)
# Requirement already satisfied: certifi<2024.0.0,>=2023.7.22 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nba_api) (2023.11.17)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nba_api) (1.26.2)
# Requirement already satisfied: requests<3.0,>=2.31 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nba_api) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from elastic-transport<9,>=8->elasticsearch) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0,>=2.31->nba_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0,>=2.31->nba_api) (3.4)

# %%
from dotenv import load_dotenv
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder
from elasticsearch import Elasticsearch, helpers
import os


load_dotenv()
 
elastic_user=os.getenv('ES_USER')
elastic_password=os.getenv('ES_PASSWORD')

url = f"https://{elastic_user}:{elastic_password}@localhost:9200"
es = Elasticsearch(url, ca_certs = "./http_ca.crt", verify_certs = True)
 
print(es.info())
# Out:
# {'name': 'liuxgm.local', 'cluster_name': 'elasticsearch', 'cluster_uuid': 'h2QwONxsT4Kt-lTRKmPrhg', 'version': {'number': '8.12.0', 'build_flavor': 'default', 'build_type': 'tar', 'build_hash': '1665f706fd9354802c02146c1e6b5c0fbcddfbc9', 'build_date': '2024-01-11T10:05:27.953830042Z', 'build_snapshot': False, 'lucene_version': '9.9.1', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'}

# %%
nba_teams = teams.get_teams()
celtics = [team for team in nba_teams if team['abbreviation'] == 'BOS'][0]
celtics_id = celtics['id']

# %%
celtics
# Out:
# {'id': 1610612738,
#  'full_name': 'Boston Celtics',
#  'abbreviation': 'BOS',
#  'nickname': 'Celtics',
#  'city': 'Boston',
#  'state': 'Massachusetts',
#  'year_founded': 1946}

# %%
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id)
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 0     22023  1610612738               BOS  Boston Celtics  0022300706
# 1     22023  1610612738               BOS  Boston Celtics  0022300684
# 2     22023  1610612738               BOS  Boston Celtics  0022300670
# 3     22023  1610612738               BOS  Boston Celtics  0022300659
# 4     22023  1610612738               BOS  Boston Celtics  0022300646
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2024-02-04  BOS vs. MEM  W  242  131  ...   0.889    17    40   57   30
# 1  2024-02-01  BOS vs. LAL  L  240  105  ...   1.000    14    40   54   30
# 2  2024-01-30  BOS vs. IND  W  240  129  ...   0.818     7    33   40   25
# 3  2024-01-29  BOS vs. NOP  W  240  118  ...   0.750     6    34   40   27
# 4  2024-01-27  BOS vs. LAC  L  240   96  ...   0.875    18    34   52   21
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0   12    4   10  13        40.0
# 1    4   12   15  19        -9.0
# 2    6    9   10  16         5.0
# 3    7    5   11  15         6.0
# 4    2    9   11  13       -19.0
#
# [5 rows x 28 columns]

# %%
current_season = games.loc[(games['GAME_DATE'] >= '2023-10-24') & (games['GAME_DATE'] <= '2024-06-20')]
current_season
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 0      22023  1610612738               BOS  Boston Celtics  0022300706
# 1      22023  1610612738               BOS  Boston Celtics  0022300684
# 2      22023  1610612738               BOS  Boston Celtics  0022300670
# 3      22023  1610612738               BOS  Boston Celtics  0022300659
# 4      22023  1610612738               BOS  Boston Celtics  0022300646
# 5      22023  1610612738               BOS  Boston Celtics  0022300630
# 9   2024-01-17  BOS vs. SAS  W  240  117  ...   0.789    12    42   54   22
# 10  2024-01-15    BOS @ TOR  W  240  105  ...   0.920     5    48   53   20
# 11  2024-01-13  BOS vs. HOU  W  239  145  ...   0.760    10    40   50   26
# 12  2024-01-11    BOS @ MIL  L  241  102  ...   0.833     6    25   31   22
# 13  2024-01-10  BOS vs. MIN  W  263  127  ...   0.968     7    39   46   21
# 14  2024-01-08    BOS @ IND  L  240  131  ...   0.690    13    29   42   26
# 15  2024-01-06    BOS @ IND  W  240  118  ...   0.526    13    43   56   26
# 16  2024-01-05  BOS vs. UTA  W  240  126  ...   0.861     9    47   56   24
# 17  2024-01-02    BOS @ OKC  L  241  123  ...   0.828    17    30   47   33
# 18  2023-12-31    BOS @ SAS  W  240  134  ...   0.773    13    44   57   29
# 19  2023-12-29  BOS vs. TOR  W  239  120  ...   0.850    13    39   52   29
# 20  2023-12-28  BOS vs. DET  W  266  128  ...   0.840    11    32   43   25
# 21  2023-12-25    BOS @ LAL  W  240  126  ...   0.750    11    33   44   31
# 22  2023-12-23    BOS @ LAC  W  241  145  ...   0.786    15    36   51   33
# 23  2023-12-20    BOS @ SAC  W  239  144  ...   0.833    14    36   50   35
# 24  2023-12-19    BOS @ GSW  L  264  126  ...   0.882    18    37   55   28
# 25  2023-12-17  BOS vs. ORL  W  239  114  ...   0.875    10    45   55   18
# 26  2023-12-15  BOS vs. ORL  W  240  128  ...   0.700     9    25   34   31
# 27  2023-12-14  BOS vs. CLE  W  240  116  ...   0.850    13    31   44   22
# 28  2023-12-12  BOS vs. CLE  W  241  120  ...   1.000    12    33   45   23
# 29  2023-12-08  BOS vs. NYK  W  240  133  ...   0.857     8    26   34   24
# 30  2023-12-04    BOS @ IND  L  239  112  ...   0.667    13    43   56   27
# 31  2023-12-01  BOS vs. PHI  W  239  125  ...   0.861    10    36   46   25
# 32  2023-11-28  BOS vs. CHI  W  241  124  ...   0.750    11    41   52   36
# 33  2023-11-26  BOS vs. ATL  W  239  113  ...   0.800    18    40   58   24
# 34  2023-11-24    BOS @ ORL  L  240   96  ...   0.730     4    27   31   17
# 35  2023-11-22  BOS vs. MIL  W  240  119  ...   0.824     4    39   43   27
# 36  2023-11-20    BOS @ CHA  L  264  118  ...   0.643    11    37   48   19
# 37  2023-11-19    BOS @ MEM  W  241  102  ...   0.800     9    36   45   20
# 38  2023-11-17    BOS @ TOR  W  240  108  ...   0.889     8    36   44   29
# 39  2023-11-15    BOS @ PHI  W  239  117  ...   0.789    12    33   45   23
# 40  2023-11-13  BOS vs. NYK  W  238  114  ...   0.938     8    29   37   27
# 41  2023-11-11  BOS vs. TOR  W  242  117  ...   0.615     5    41   46   30
# 42  2023-11-10  BOS vs. BKN  W  241  121  ...   0.714    17    35   52   29
# 43  2023-11-08    BOS @ PHI  L  241  103  ...   0.842     9    34   43   28
# 44  2023-11-06    BOS @ MIN  L  265  109  ...   0.765    11    34   45   20
# 45  2023-11-04    BOS @ BKN  W  240  124  ...   0.852    10    40   50   22
# 46  2023-11-01  BOS vs. IND  W  239  155  ...   0.964    11    46   57   27
# 47  2023-10-30    BOS @ WAS  W  243  126  ...   0.714    15    36   51   31
# 48  2023-10-27  BOS vs. MIA  W  239  119  ...   0.684    16    39   55   20
# 49  2023-10-25    BOS @ NYK  W  241  108  ...   0.846     7    39   46   18
#
#     STL  BLK  TOV  PF  PLUS_MINUS
# 0    12    4   10  13        40.0
# 1     4   12   15  19        -9.0
# 2     6    9   10  16         5.0
# 3     7    5   11  15         6.0
# 4     2    9   11  13       -19.0
# 5     4    5   11  10        33.0
# 6     7    8    6  20         9.0
# 7    10   12   16  17         9.0
# 8     5    2    2  17        -2.0
# 9     5    6   12  15        19.0
# 10    3    7   12  16         9.0
# 11    7    8   11  21        32.0
# 12    5    5    6  13       -33.0
# 13    5    4    8  19         7.0
# 14    3    8   15  20        -2.0
# 15    6    6   17  20        17.0
# 16    9    8   12  23        29.0
# 17    7   10   14  15        -4.0
# 18    6    7   10  12        33.0
# 19    3    6   16  17         2.0
# 20   10    4   12  15         6.0
# 21    8    7    8  17        11.0
# 22    4    5    9  19        37.0
# 23    6   10    9  17        25.0
# 24    6    5    8  13        -6.0
# 25    4   10   14  19        17.0
# 26   14    7   10  22        17.0
# 27    7    8   13  15         9.0
# 28    9    9   13  13         7.0
# 29    8    5    7  19        10.0
# 30    5    9   17  19       -10.0
# 31   10    8   20  18         6.0
# 32    6    9   16  18        27.0
# 33    9    3   12  19        10.0
# 34   10    4   14  18       -17.0
# 35    3    5   15  15         3.0
# 36    6    8   13  15        -3.0
# 37    6   10   17  19         2.0
# 38    5    4   10  13         3.0
# 39    7    8    9  15        10.0
# 40    3    3   11  22        16.0
# 41    1    4   12  14        23.0
# 42    5    3    7  13        14.0
# 43    8    6   12  13        -3.0
# 44   13    2   16  26        -5.0
# 45    4    6   11  17        10.0
# 46    5    2   11  19        51.0
# 47   11    6   17  21        19.0
# 48    7    6   15  19         8.0
# 49    6   11   13  22         4.0
#
# [50 rows x 28 columns]

# %%
current_season.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Create index

# %%
INDEX_NAME = "boston_celtics_current_season"

es.indices.create(index = INDEX_NAME)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'boston_celtics_current_season'})

# %%
def doc_generator(df, timeframe):
    for index, document in df.iterrows():
        yield {
            "_index": INDEX_NAME, 
            "_id": f"{document['GAME_ID']}",
            "_source": document.to_dict(),
        }

# %%
helpers.bulk(es, doc_generator(current_season, index))
es.indices.refresh(index=index)
# Out:
# ObjectApiResponse({'_shards': {'total': 2, 'successful': 1, 'failed': 0}})

# %% [markdown]
# # Search

# %%
search_query = {
    "query": {
        "match": {
            "WL": "W"
        }
    }
}

games_won = es.count(index="boston_celtics_current_season", body=search_query)

# %%
print(f"The Celtics won {games_won['count']} games this season so far.")
# Out:
# The Celtics won 38 games this season so far.

# %%
streak_query = {
  "size": 1000,  
  "sort": [
    {
      "GAME_DATE": {
        "order": "asc"
      }
    }
  ],
  "_source": ["GAME_DATE", "WL"]
}

# %%
streak_search = es.search(
    index=INDEX_NAME,
    body=streak_query)

# %%
gs = [hit['_source'] for hit in streak_search['hits']['hits']]

# %%
streaks = []
current_streak = 1
for i in range(1, len(gs)):
    if gs[i]['WL'] == gs[i-1]['WL']:
        current_streak += 1
    else:
        streaks.append((gs[i-1]['WL'], current_streak))
        current_streak = 1


streaks.append((gs[-1]['WL'], current_streak))
top_streaks = sorted(streaks, key=lambda x: x[1], reverse=True)[:5]
print(top_streaks)
# Out:
# [('W', 6), ('W', 6), ('W', 5), ('W', 5), ('W', 3)]
